# %%
import pytest
from xagg_new.dummy_module import dummy_foo


def test_dummy():
    assert dummy_foo(4) == (4 + 4)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-96d9768c40f7> in <module>
#       1 import pytest
# ----> 2 from xagg_new.dummy_module import dummy_foo
#       3
#       4
#       5 def test_dummy():
#
# ModuleNotFoundError: No module named 'xagg_new'
